# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

# %%
def detect_and_compute_sift(image_path):

    image = cv2.imread(image_path)
    gray_image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
    sift = cv2.SIFT_create()

    keypoints,descriptors = sift.detectAndCompute(gray_image,None)
    print(len(keypoints))
    # print(f'descriptors: {descriptors}')
    return image, keypoints,descriptors
image_path = r"C:\Users\saive\Desktop\Github\Computer-Vision\images\face.png"
image, keypoints, descriptors = detect_and_compute_sift(image_path)
# Out:
# 307

# %%
def visualize_key_points(image,keypoints):
    image_with_keypoints = cv2.drawKeypoints(
        image,
        keypoints,
        None,
        flags = cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS
    )
    return image_with_keypoints

image_with_key_points = visualize_key_points(image,keypoints)

# %%
plt.figure(figsize = (10,8))
plt.imshow(cv2.cvtColor(image_with_key_points,cv2.COLOR_BGR2RGB))
plt.title('The sift keypoint detector')
plt.axis('off');

# %%
if descriptors is not None:
    print(f'The dimension of descriptor is {descriptors.shape}')
    print(f'Each descriptor shape is {descriptors[1].shape}')

    if len(descriptors)>0:
        plt.figure(figsize=(10,8))
        plt.bar(range(descriptors.shape[1]),descriptors[0])
        plt.title('The first SIFT detector')
        plt.tight_layout()
        plt.show()
# Out:
# The dimension of descriptor is (307, 128)
# Each descriptor shape is (128,)

# %%
# This line
